# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as pyplot

# %%
# Load the data
df = pd.read_csv("data/beers.csv")

# %%
# Explore the data
print(f"Dataset contains {df.shape[0]} rows and {df.shape[1]} columns.")
print(f"Dataset contains {df.isnull().sum().sum()} missing values.")
print(f"Dataset contains {df.duplicated().sum()} duplicated rows.")

# %%
df.info()

# %%
df["state"].unique()

# %%
df["style"].unique()

# %%
df = df.dropna()
df = df.drop_duplicates()
    # Create a new df. Group by state and style and count the number of beers
df_grouped = df.groupby(["state", "style"]).size().reset_index(name="count")
df_grouped
# Out:
# <Axes: xlabel='state', ylabel='count'>

# %%
df_grouped
# Out:
#     state                           style  count
# 0      AK        American Amber / Red Ale      1
# 1      AK             American Blonde Ale      2
# 2      AK                    American IPA      6
# 3      AK         American Pale Ale (APA)      2
# 4      AL  American Double / Imperial IPA      1
# ..    ...                             ...    ...
# 191    WV         American Pale Ale (APA)      1
# 192    WY        American Amber / Red Ale      2
# 193    WY                    American IPA      2
# 194    WY         American Pale Ale (APA)      2
# 195    WY         American Pale Wheat Ale      1
#
# [196 rows x 3 columns]
