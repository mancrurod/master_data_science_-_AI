# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/TB_Burden_Country.csv')
print(f"Data loaded successfully.")
# Out:
# Data loaded successfully.

# %%
df.sample(5)

# %%
df.columns

# %%
df.dropna()
df.drop_duplicates()
df.drop([
'ISO 2-character country/territory code',
'ISO numeric country/territory code',
'Estimated prevalence of TB (all forms) per 100 000 population, low bound',
'Estimated prevalence of TB (all forms) per 100 000 population, high bound',
'Estimated prevalence of TB (all forms), low bound',
'Estimated prevalence of TB (all forms), high bound',
'Estimated number of deaths from TB in people who are HIV-positive, low bound',
'Estimated number of deaths from TB in people who are HIV-positive, high bound',
'Estimated number of deaths from TB (all forms, excluding HIV), low bound',
'Estimated number of deaths from TB (all forms, excluding HIV), high bound',
'Estimated incidence of TB cases who are HIV-positive per 100 000 population, low bound',
'Estimated incidence of TB cases who are HIV-positive per 100 000 population, high bound',
'Estimated incidence of TB cases who are HIV-positive, low bound',
'Estimated incidence of TB cases who are HIV-positive, high bound',
'Case detection rate (all forms), percent, low bound',
'Case detection rate (all forms), percent, high bound',
'Method to derive mortality estimates',
'Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, low bound',
'Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, high bound',
'Estimated incidence (all forms) per 100 000 population, low bound',
'Estimated incidence (all forms) per 100 000 population, high bound',
'Estimated HIV in incident TB (percent), low bound',
    'Estimated HIV in incident TB (percent), high bound',
    'Method to derive incidence estimates',
    'Method to derive prevalence estimates',
    'Method to derive TBHIV estimates'
], axis=1, inplace=True)

# %%
df

# %%
df.groupby('Country or territory name')['Estimated number of deaths from TB (all forms, excluding HIV)'].max().sort_values(ascending=False).head(10)
df.plot(kind='bar')
plt.title('Top 10 countries with most deaths from TB')
plt.xlabel('Country')
plt.ylabel('Number of deaths')
plt.xticks(rotation=45, ha='right')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 df.groupby('Country or territory name')['Estimated number of deaths from TB (all forms, excluding HIV)'].max().sort_values(ascending=False).head(10)
# ----> 2 df.plot(kind='bar')
#       3 plt.title('Top 10 countries with most deaths from TB')
#       4 plt.xlabel('Country')
#
# File c:\Users\manue\miniconda3\envs\tuberculosis\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\manue\miniconda3\envs\tuberculosis\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\manue\miniconda3\envs\tuberculosis\Lib\site-packages\pandas\plotting\_matplotlib\core.py:501, in MPLPlot.generate(self)
#     499 self._compute_plot_data()
#     500 fig = self.fig
# --> 501 self._make_plot(fig)
#     502 self._add_table()
#     503 self._make_legend()
#
# File c:\Users\manue\miniconda3\envs\tuberculosis\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1954, in BarPlot._make_plot(self, fig)
#    1952 else:
#    1953     w = self.bar_width / K
# -> 1954     rect = self._plot(
#    1955         ax,
#    1956         self.ax_pos + (i + 0.5) * w,
#    1957         y,
#    1958         w,
#    1959         start=start,
#    1960         label=label,
#    1961         log=self.log,
#    1962         **kwds,
#    1963     )
#    1964 self._append_legend_handles_labels(rect, label)
#
# File c:\Users\manue\miniconda3\envs\tuberculosis\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1884, in BarPlot._plot(cls, ax, x, y, w, start, log, **kwds)
#    1873 @classmethod
#    1874 def _plot(  # type: ignore[override]
#    1875     cls,
#    (...)
#    1882     **kwds,
#    1883 ):
# -> 1884     return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#
# File c:\Users\manue\miniconda3\envs\tuberculosis\Lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File c:\Users\manue\miniconda3\envs\tuberculosis\Lib\site-packages\matplotlib\axes\_axes.py:2649, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2647     else:  # horizontal
#    2648         r.sticky_edges.x.append(l)
# -> 2649     self.add_patch(r)
#    2650     patches.append(r)
#    2652 if xerr is not None or yerr is not None:
#
# File c:\Users\manue\miniconda3\envs\tuberculosis\Lib\site-packages\matplotlib\axes\_base.py:2446, in _AxesBase.add_patch(self, p)
#    2444 if p.get_clip_path() is None:
#    2445     p.set_clip_path(self.patch)
# -> 2446 self._update_patch_limits(p)
#    2447 self._children.append(p)
#    2448 p._remove_method = self._children.remove
#
# File c:\Users\manue\miniconda3\envs\tuberculosis\Lib\site-packages\matplotlib\axes\_base.py:2488, in _AxesBase._update_patch_limits(self, patch)
#    2486         updatey = False
#    2487 trf_to_data = patch_trf - self.transData
# -> 2488 xys = trf_to_data.transform(vertices)
#    2489 self.update_datalim(xys, updatex=updatex, updatey=updatey)
#
# File c:\Users\manue\miniconda3\envs\tuberculosis\Lib\site-packages\matplotlib\transforms.py:1495, in Transform.transform(self, values)
#    1492 values = values.reshape((-1, self.input_dims))
#    1494 # Transform the values
# -> 1495 res = self.transform_affine(self.transform_non_affine(values))
#    1497 # Convert the result back to the shape of the input values.
#    1498 if ndim == 0:
#
# File c:\Users\manue\miniconda3\envs\tuberculosis\Lib\site-packages\matplotlib\transforms.py:2410, in CompositeGenericTransform.transform_affine(self, values)
#    2408 def transform_affine(self, values):
#    2409     # docstring inherited
# -> 2410     return self.get_affine().transform(values)
#
# File c:\Users\manue\miniconda3\envs\tuberculosis\Lib\site-packages\matplotlib\transforms.py:2436, in CompositeGenericTransform.get_affine(self)
#    2434     return self._b.get_affine()
#    2435 else:
# -> 2436     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2437                            self._a.get_affine().get_matrix()))
#
# KeyboardInterrupt:

# %%
df_plot_1 = df.groupby('Country or territory name')['Estimated number of deaths from TB (all forms, excluding HIV)'].max().sort_values(ascending=False).head(10)
df_plot_1.plot(kind='bar')
plt.title('Top 10 countries with most deaths from TB')
plt.xlabel('Country')
plt.ylabel('Number of deaths')
plt.xticks(rotation=45, ha='right')
plt.show();

# %%
df_filtered.columns

# %%
df_plot_2 = df_filtered.groupby('Region')['Estimated number of incident cases (all forms)'].max().sort_values(ascending=False)
pyplot.title('Top regions with most incident cases of TB')
df_plot_2.plot(kind='pie', autopct='%1.1f%%')
pyplot.ylabel('Region')
pyplot.show();
